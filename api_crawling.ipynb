# %%
SERVICE_KEY = '74696d5876696d68333772476d4c62'

# %%
URL = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/1/100/' # f 스트링 사용
URL
# Out:
# 'http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/1/100/'

# %%
import requests
import json
import pandas as pd

req = requests.get(URL)
req
# Out:
# <Response [200]>

# %%
# content

# %%
content = req.json()
# content
result = pd.DataFrame(content['tbLnOpendataRtmsV']['row'])
result
# Out:
#    ACC_YEAR SGG_CD SGG_NM BJDONG_CD BJDONG_NM LAND_GBN LAND_GBN_NM BONBEON  \
# 0      2024  11560   영등포구     10200    영등포동1가        1          대지    0121
# 1      2024  11740    강동구     10900       천호동        1          대지    0090
# 2      2024  11320    도봉구     10800       도봉동        1          대지    0051
# 3      2024  11545    금천구     10200       독산동        1          대지    1006
# 4      2024  11590    동작구     10300      상도1동        1          대지    0419
# ..      ...    ...    ...       ...       ...      ...         ...     ...
# 95     2024  11215    광진구     10300       구의동        1          대지    0035
# 96     2024  11740    강동구     10700       암사동        1          대지    0414
# 97     2024  11410   서대문구     11900      북가좌동        1          대지    0371
# 98     2024  11590    동작구     10700       사당동        1          대지    1133
# 99     2024  11440    마포구     10800       대흥동        1          대지    0012
#
#    BUBEON      BLDG_NM  ... OBJ_AMT BLDG_AREA  TOT_AREA  FLOOR  RIGHT_GBN  \
# 0    0005     여의도리슈빌DS  ...   20600     21.41     31.43    7.0
# 1    0002         도우빌라  ...   36700     48.69     46.66   -1.0
# 2    0012     중흥에스-클래스  ...   55000     85.00      0.00    3.0
# 3    0115    중앙하이빌1동2동  ...   23000     28.68     14.88    4.0
# 4    0003        종로빌리지  ...   40000     69.13     48.37    3.0
# ..    ...          ...  ...     ...       ...       ...    ...        ...
# 95   0048         금화빌라  ...   20000     38.18     24.90    1.0
# 96   0002      롯데캐슬퍼스트  ...  112500     59.99      0.00   28.0
# 97   0001        월드컵현대  ...   81500     84.93      0.00   12.0
# 98   0000        삼성래미안  ...  134000    158.47      0.00   13.0
# 99   0027  이대역 푸르지오 시티  ...   24000     28.80     39.60    4.0
#
#    CNTL_YMD BUILD_YEAR HOUSE_TYPE REQ_GBN RDEALER_LAWDNM
# 0                 2020       오피스텔    중개거래        서울 영등포구
# 1                 1991      연립다세대    중개거래         서울 강동구
# 2                 2004        아파트    중개거래         서울 도봉구
# 3                 2016      연립다세대     직거래
# 4                 1991      연립다세대    중개거래         서울 강남구
# ..      ...        ...        ...     ...            ...
# 95                1997      연립다세대    중개거래         서울 광진구
# 96                2008        아파트    중개거래         서울 강동구
# 97                1998        아파트    중개거래        서울 서대문구
# 98                2003        아파트    중개거래         서울 동작구
# 99                2013       오피스텔    중개거래         서울 마포구
#
# [100 rows x 21 columns]

# %%
URL = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/xml/tbLnOpendataRtmsV/1/5/' # f 스트링 사용
URL
# Out:
# 'http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/xml/tbLnOpendataRtmsV/1/5/'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

req = requests.get(URL)
soup = BeautifulSoup(req.content, 'lxml')
# print(soup.prettify())
# Out:
# C:\Users\imhye\AppData\Local\Temp\ipykernel_13584\1385855961.py:6: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(req.content, 'lxml')

# %%
years            = soup.find_all('acc_year')         # 접수년월
sgg_cds          = soup.find_all('sgg_cd')           # 자치구코드
sgg_nms          = soup.find_all('sgg_nm')           # 자치구명
bjdong_cds       = soup.find_all('bjdong_cd')        # 법정동코드
bjdong_nms       = soup.find_all('bjdong_nm')        # 법정동명
land_gbns        = soup.find_all('land_gbn')         # 지번구분
land_gbn_nms     = soup.find_all('land_gbn_nm')      # 지번구분명
land_gbn_nms     = soup.find_all('land_gbn_nm')      # 지번구분명
bonbeons         = soup.find_all('bonbeon')          # 본번
bubeons          = soup.find_all('bubeon')           # 부번
bldg_nms         = soup.find_all('bldg_nm')          # 건물명
deal_ymds        = soup.find_all('deal_ymd')         # 계약일
obj_amts         = soup.find_all('obj_amt')          # 물건금액(만원)
bldg_areas       = soup.find_all('bldg_area')        # 건물면적(㎡)
tot_areas        = soup.find_all('tot_area')         # 토지면적(㎡)
floors           = soup.find_all('floor')            # 층
right_gbns       = soup.find_all('right_gbn')        # 권리구분
cntl_ymds        = soup.find_all('cntl_ymd')         # 취소일
build_years      = soup.find_all('build_years')      # 건축년도
house_types      = soup.find_all('house_type')       # 건물용도
req_gbn          = soup.find_all('req_gbn')          # 신고구분
rdealer_lawdnms  = soup.find_all('rdealer_lawdnm')   # 신고한 개업공인중개사 시군구명
year_list           = []
sgg_cd_list         = []
bldg_nm_list        = []
obj_amt_list        = []
house_type_list     = []
rdealer_lawdnm_list = []
for year, sgg_cd, bldg_nm, obj_amt, house_type, rdealer_lawdnm in zip(years, sgg_cds, bldg_nms, obj_amts, house_types, rdealer_lawdnms):
  year_list.append(year.get_text())
  sgg_cd_list.append(sgg_cd.get_text())
  bldg_nm_list.append(bldg_nm.get_text())
  obj_amt_list.append(obj_amt.get_text())
  house_type_list.append(house_type.get_text())
  rdealer_lawdnm_list.append(rdealer_lawdnm.get_text())
df = pd.DataFrame({
    "acc_year": year_list, 
    "sgg_cd": sgg_cd_list, 
    "bldg_nm" : bldg_nm_list,
    "obj_amt": obj_amt_list,
    "house_type" : house_type_list,
    "rdealer_lawdnm": rdealer_lawdnm_list
})
df
# Out:
#   acc_year sgg_cd    bldg_nm obj_amt house_type rdealer_lawdnm
# 0     2024  11560   여의도리슈빌DS   20600       오피스텔        서울 영등포구
# 1     2024  11740       도우빌라   36700      연립다세대         서울 강동구
# 2     2024  11320   중흥에스-클래스   55000        아파트         서울 도봉구
# 3     2024  11545  중앙하이빌1동2동   23000      연립다세대
# 4     2024  11590      종로빌리지   40000      연립다세대         서울 강남구

# %% [markdown]
# ## 공공데이터 포털
# - 국토교통부

# %%
import requests
import json
import pandas as pd
import xmltodict

PUBLIC_SERVICE_KEY = 'uoZwGxpkaaGdi0fo%2Fnsa%2FibOP7dxmXVxEhzWSfAKdYzZqiqQqVTLqTHs81EZznXgdZGjT7Xv3XiHio7U0T%2F2Ug%3D%3D'

# serviceKey = '인증키 입력'
pageNo = 1 # 페이지 번호
numOfRows = 500 # 한 페이지 결과수
LAWD_CD = 11500 # 지역코드
DEAL_YMD = 202101 # 계약월
url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey={PUBLIC_SERVICE_KEY}&pageNo={pageNo}&numOfRows={numOfRows}&LAWD_CD={LAWD_CD}&DEAL_YMD={DEAL_YMD}'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
 req.text
#contents = xmltodict.parse(req.text)
#data = pd.DataFrame(contents['response']['body']['items']['item'])
#data.head
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>99</resultCode><resultMsg>SERVICE ACCESS DENIED ERROR.</resultMsg></header></response>'

# %% [markdown]
# ## 다중 데이터 수집

# %%
SERVICE_KEY = '74696d5876696d68333772476d4c62'
URL = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/1/1000/' # f 스트링 사용
URL = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/1001/2000/'
URL = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/2001/3000/'
# Out:
# 'http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/1/100/'

# %%
SERVICE_KEY = '74696d5876696d68333772476d4c62'

for i in range(10):  
    start_index = i * 1000 + 1
    end_index = (i + 1) * 1000

    URL = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/{start_index}/{end_index}/'
    print(URL)
# Out:
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/1/1000/
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/1001/2000/
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/2001/3000/
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/3001/4000/
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/4001/5000/
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/5001/6000/
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/6001/7000/
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/7001/8000/
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/8001/9000/
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/9001/10000/

# %%
data = None
for j in range(1,5):
    url = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/{1+((j-1)*1000)}/{j*1000}'
    # url = f'http://openapi.seoul.go.kr:8088/{service_key}/json/tbLnOpendataRentV/1/1000/2023/11560'
    print(url)
    req = requests.get(url)
    content = req.json()
    con = content['tbLnOpendataRtmsV']['row']
    result = pd.DataFrame(con)
    data = pd.concat([data, result])
data = data.reset_index(drop=True)
data.head()
# Out:
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/1/1000
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/1001/2000
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/2001/3000
# http://openapi.seoul.go.kr:8088/74696d5876696d68333772476d4c62/json/tbLnOpendataRtmsV/3001/4000
#   ACC_YEAR SGG_CD SGG_NM BJDONG_CD BJDONG_NM LAND_GBN LAND_GBN_NM BONBEON  \
# 0     2024  11560   영등포구     10200    영등포동1가        1          대지    0121
# 1     2024  11740    강동구     10900       천호동        1          대지    0090
# 2     2024  11320    도봉구     10800       도봉동        1          대지    0051
# 3     2024  11545    금천구     10200       독산동        1          대지    1006
# 4     2024  11590    동작구     10300      상도1동        1          대지    0419
#
#   BUBEON    BLDG_NM  ... OBJ_AMT BLDG_AREA  TOT_AREA  FLOOR  RIGHT_GBN  \
# 0   0005   여의도리슈빌DS  ...   20600     21.41     31.43    7.0
# 1   0002       도우빌라  ...   36700     48.69     46.66   -1.0
# 2   0012   중흥에스-클래스  ...   55000     85.00      0.00    3.0
# 3   0115  중앙하이빌1동2동  ...   23000     28.68     14.88    4.0
# 4   0003      종로빌리지  ...   40000     69.13     48.37    3.0
#
#   CNTL_YMD BUILD_YEAR HOUSE_TYPE REQ_GBN RDEALER_LAWDNM
# 0                2020       오피스텔    중개거래        서울 영등포구
# 1                1991      연립다세대    중개거래         서울 강동구
# 2                2004        아파트    중개거래         서울 도봉구
# 3                2016      연립다세대     직거래
# 4                1991      연립다세대    중개거래         서울 강남구
#
# [5 rows x 21 columns]

# %%
data
# Out:
#      ACC_YEAR SGG_CD SGG_NM BJDONG_CD BJDONG_NM LAND_GBN LAND_GBN_NM BONBEON  \
# 0        2024  11560   영등포구     10200    영등포동1가        1          대지    0121
# 1        2024  11740    강동구     10900       천호동        1          대지    0090
# 2        2024  11320    도봉구     10800       도봉동        1          대지    0051
# 3        2024  11545    금천구     10200       독산동        1          대지    1006
# 4        2024  11590    동작구     10300      상도1동        1          대지    0419
# ...       ...    ...    ...       ...       ...      ...         ...     ...
# 3995     2023  11290    성북구     13900       석관동        1          대지    0073
# 3996     2023  11440    마포구     10500       용강동        1          대지    0502
# 3997     2023  11680    강남구     10600       대치동        1          대지    1014
# 3998     2024  11200    성동구     11300       옥수동        1          대지    0561
# 3999     2023  11305    강북구     10100       미아동        1          대지    0258
#
#      BUBEON     BLDG_NM  ... OBJ_AMT BLDG_AREA  TOT_AREA  FLOOR  RIGHT_GBN  \
# 0      0005    여의도리슈빌DS  ...   20600     21.41     31.43    7.0
# 1      0002        도우빌라  ...   36700     48.69     46.66   -1.0
# 2      0012    중흥에스-클래스  ...   55000     85.00      0.00    3.0
# 3      0115   중앙하이빌1동2동  ...   23000     28.68     14.88    4.0
# 4      0003       종로빌리지  ...   40000     69.13     48.37    3.0
# ...     ...         ...  ...     ...       ...       ...    ...        ...
# 3995   0014     (73-14)  ...   29000     28.49     20.41    5.0
# 3996   0000    래미안마포리버웰  ...  170000     84.97      0.00    3.0
# 3997   0003        대치삼성  ...  271000     97.35      0.00   17.0
# 3998   0000  래미안 옥수 리버젠  ...  220000    113.52      0.00   13.0
# 3999   0222        가람빌라  ...   15000     52.60     35.90   -1.0
#
#      CNTL_YMD BUILD_YEAR HOUSE_TYPE REQ_GBN  RDEALER_LAWDNM
# 0                   2020       오피스텔    중개거래         서울 영등포구
# 1                   1991      연립다세대    중개거래          서울 강동구
# 2                   2004        아파트    중개거래          서울 도봉구
# 3                   2016      연립다세대     직거래
# 4                   1991      연립다세대    중개거래          서울 강남구
# ...       ...        ...        ...     ...             ...
# 3995                2023      연립다세대    중개거래          서울 성북구
# 3996                2015        아파트    중개거래  서울 마포구, 서울 성동구
# 3997                2000        아파트    중개거래  서울 강남구, 서울 금천구
# 3998                2012        아파트    중개거래          서울 성동구
# 3999                1986      연립다세대    중개거래          서울 강북구
#
# [4000 rows x 21 columns]
